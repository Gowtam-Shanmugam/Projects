# %% [markdown]
# - Steps to follow:
#
#
# ### Step 1 : Basic Understanding of Data
# ### Step 2 : Cleaning of Data
# ### Step 3 : Data Analysis and Insights
# ### Step 4 : Data Preparation
# ### Step 5 : Modelling and Model evaluation

# %% [markdown]
# # Dataset Information
# - AGE:    Age in years
# - SEX:    1 = Male; 0 = Female
# - CP:    Chest Pain type
# - TRESTBPS:   Resting Blood Pressure (in mm Hg on Admission to the Hospital)
# - CHOL:    Serum Cholestoral in mg/dl
# - FPS:    Fasting Blood Sugar > 120 mg/dl (1 = True; 0 = False)
# - RESTECG:    Resting Electrocardiographic Results
# - THALACH:    Maximum Heart Rate Achieved
# - EXANG:    Exercise induced Angina (1 = yes; 0 = no)
# - OLDPEAK:    ST Depression induced by Exercise Relative to Rest
# - SLOPE:    The Slope of the Peak Exercise ST Segment
# - CA:   Number of Major Vessels (0-3) Colored by Flourosopy
# - THAL:    A blood disorder called Thalassemia (3 = Normal; 6 = Fixed Defect; 7 = Reversable Defect)
# - TARGET:    1 or 0

# %% [markdown]
# # Import the relevant Libraries

# %%
#to load an  dataset 
import pandas as pd

import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
# sns.set()

from sklearn.metrics import accuracy_score, f1_score, confusion_matrix,classification_report
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.tree import DecisionTreeClassifier

# Regreesion
# from sklearn.tree import DecisionTreeRegressor

# %% [markdown]
# - AGE:    Age in years
# - SEX:    1 = Male; 0 = Female
# - CP:    Chest Pain type
# - TRESTBPS:   Resting Blood Pressure (in mm Hg on Admission to the Hospital)
# - CHOL:    Serum Cholestoral in mg/dl
# - FPS:    Fasting Blood Sugar > 120 mg/dl (1 = True; 0 = False)
# - RESTECG:    Resting Electrocardiographic Results
# - THALACH:    Maximum Heart Rate Achieved
# - EXANG:    Exercise induced Angina (1 = yes; 0 = no)
# - OLDPEAK:    ST Depression induced by Exercise Relative to Rest
# - SLOPE:    The Slope of the Peak Exercise ST Segment
# - CA:   Number of Major Vessels (0-3) Colored by Flourosopy
# - THAL:    A blood disorder called Thalassemia (3 = Normal; 6 = Fixed Defect; 7 = Reversable Defect)
# - TARGET:    1 or 0

# %% [markdown]
# # Step 1: Basic understanding of data

# %%
# Load an dataset
heart = pd.read_csv('heart.csv')

# %%
# Number of Rows and Columns
heart.shape
# Out:
# (303, 14)

# %%
# first five rows 

heart.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
# Column Names
heart.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %% [markdown]
# - AGE:    Age in years
# - SEX:    1 = Male; 0 = Female
# - CP:    Chest Pain type
# - TRESTBPS:   Resting Blood Pressure (in mm Hg on Admission to the Hospital)
# - CHOL:    Serum Cholestoral in mg/dl
# - FPS:    Fasting Blood Sugar > 120 mg/dl (1 = True; 0 = False)
# - RESTECG:    Resting Electrocardiographic Results
# - THALACH:    Maximum Heart Rate Achieved
# - EXANG:    Exercise induced Angina (1 = yes; 0 = no)
# - OLDPEAK:    ST Depression induced by Exercise Relative to Rest
# - SLOPE:    The Slope of the Peak Exercise ST Segment
# - CA:   Number of Major Vessels (0-3) Colored by Flourosopy
# - THAL:    A blood disorder called Thalassemia (3 = Normal; 6 = Fixed Defect; 7 = Reversable Defect)
# - TARGET:    1 or 0

# %% [markdown]
# # Column INFO

# %%
heart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
# Column Data Types¶
heart.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %% [markdown]
# - After a quick glimpse of the data set to get an initial understanding of the variables and their formats, the next step is to check for the number of missing values in each column.

# %% [markdown]
# # Step 2: Data Cleaning

# %% [markdown]
# - Missing Values¶

# %%
heart.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %% [markdown]
# # Now there are no null values. so there is no need for data cleaning.

# %%
# Data Analysis and Insights
# Minimum,maximum and average age of the persons having heart disease

# %%
heart.groupby(["target"])["age"].agg(["max","min","mean"])
# Out:
#         max  min       mean
# target
# 0        77   35  56.601449
# 1        76   29  52.496970

# %% [markdown]
# # Number of peoples having heart disease?

# %%
heart.target.value_counts()

# heart['target'].value_counts()
# Out:
# 1    165
# 0    138
# Name: target, dtype: int64

# %%
heart.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart.groupby(heart["sex"])["target"].agg(["value_counts"])
# Out:
#             value_counts
# sex target
# 0   1                 72
#     0                 24
# 1   0                114
#     1                 93

# %%
sex = ["Male", "Female"]
values = heart["target"].value_counts()
color = ["#FF0000", "#000000"]

plt.figure(figsize = (5, 7))
plt.pie(values, labels = sex, colors = color, explode = (0.1, 0), textprops = {"color":"w"}, autopct = "%.2f%%", shadow = True, startangle = 90)

plt.legend();

# %% [markdown]
# # Is sex is related to heart disease?

# %%
heart["sex"] = heart["sex"].map({0:"Female", 1:"Male"})

# %% [markdown]
# # Ratio of Male to Female is approx 1:1
#
# # Insight:Males are having more heart disease as compared to females.
#
# # Relation between Sex and Slope

# %%
sns.countplot(x = heart["sex"], hue = heart["slope"]);

# %% [markdown]
# # here slope value is higher in the case of Males

# %% [markdown]
# # How blood pressure is related with heart disease?

# %%
sns.catplot(x="target",y="trestbps",data=heart,kind='swarm')

# %% [markdown]
# # Insight: People having blood pressure between 120 - 140 are more likely to have a heart disease.

# %% [markdown]
# # How chest pain is related with heart disease¶

# %%
heart.groupby(heart["cp"])["target"].agg(["value_counts"])
# Out:
#            value_counts
# cp target
# 0  0                104
#    1                 39
# 1  1                 41
#    0                  9
# 2  1                 69
#    0                 18
# 3  1                 16
#    0                  7

# %%
sns.countplot(x = "sex",data = heart, hue = "target");

# %% [markdown]
# # Chest Pain Classification Sex-wise
# # chest pain:
#     - 0: Typical angina: chest pain related decrease blood supply to the heart
#     - 1: Atypical angina: chest pain not related to heart
#     - 2: Non-anginal pain: typically esophageal spasms (non heart related)
#     - 3: Asymptomatic: chest pain not showing signs of disease

# %%
heart.groupby("sex")["cp"].agg(["value_counts"])
# Out:
#            value_counts
# sex    cp
# Female 0             39
#        2             35
#        1             18
#        3              4
# Male   0            104
#        2             52
#        1             32
#        3             19

# %%
sns.countplot(x = "cp", data = heart, hue = "sex");

# %% [markdown]
# - Insight: Most of the peoples are having Typical angina chest pain.

# %%
# Relation between Chest Pain vs Target
sns.countplot(x = "cp", data = heart, hue = "target");

# %% [markdown]
# - Insight: Peoples having Typical angina chest pain are more likely to have heart disease.

# %% [markdown]
# # Do Males and Females absorb glucose differently?¶

# %%
heart.groupby(["sex"])["fbs"].agg(["value_counts"])
# Out:
#             value_counts
# sex    fbs
# Female 0              84
#        1              12
# Male   0             174
#        1              33

# %%
heart.head()
# Out:
#    age     sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0   63    Male   3       145   233    1        0      150      0      2.3
# 1   37    Male   2       130   250    0        1      187      0      3.5
# 2   41  Female   1       130   204    0        0      172      0      1.4
# 3   56    Male   1       120   236    0        1      178      0      0.8
# 4   57  Female   0       120   354    0        1      163      1      0.6
#
#    slope  ca  thal  target
# 0      0   0     1       1
# 1      0   0     2       1
# 2      2   0     2       1
# 3      2   0     2       1
# 4      2   0     2       1

# %%
sns.countplot(x = "fbs", data = heart, hue = "sex");

# %%
# Females have lower fasting glucose than Males

# %% [markdown]
# # Electrocardiographic relation with heart disease
#     - Value 0: normal
#
#     - Value 1: having ST-T wave abnormality (T wave inversions and/or ST elevation or depression of > 0.05 mV)
#
#     - Value 2: showing probable or definite left ventricular hypertrophy

# %%
heart.groupby(heart["restecg"])["target"].agg(["count"])
# Out:
#          count
# restecg
# 0          147
# 1          152
# 2            4

# %%
sns.countplot(x = "restecg", data = heart, hue = "target");

# %% [markdown]
# - Insight:The persons having ST-T wave abnormality resting electrocardiographic are more likely to have heart disease

# %% [markdown]
# # Thalach(maximum heart rate achieved) is related with target?

# %%
sns.catplot(x="target",y="thalach",data=heart,kind="swarm")

# %% [markdown]
# - Insight: people having heart rate between 140 to 180 are more likely to have a heart disease.

# %% [markdown]
# # Gender related differences in Electrocardiographic parameters

# %%
heart.groupby(["sex"])["restecg"].agg(["value_counts"])
# Out:
#                 value_counts
# sex    restecg
# Female 1                  49
#        0                  44
#        2                   3
# Male   0                 103
#        1                 103
#        2                   1

# %% [markdown]
# # How does gender affect angina?

# %%
heart.groupby(["sex"])["exang"].agg(["value_counts"])
# Out:
#               value_counts
# sex    exang
# Female 0                74
#        1                22
# Male   0               130
#        1                77

# %%
sns.countplot(x = "exang", data = heart, hue = "sex");

# %% [markdown]
# # Although the prevalence of angina in females is increasing,
# # Females are less likely than Males to undergo invasive management of coronary disease

# %% [markdown]
# ## How agina is related with heart disease?¶

# %%
heart.groupby(["target"])["exang"].agg(["value_counts"])
# Out:
#               value_counts
# target exang
# 0      1                76
#        0                62
# 1      0               142
#        1                23

# %%
sns.countplot(x = "exang", data = heart, hue = "target");

# %% [markdown]
# - Insight :The persons having Exercise induced angina are less likely to have heart disease.

# %% [markdown]
# # Is gender a risk factor for Coronary Artery Disease?

# %%
heart.groupby(["sex"])["ca"].agg(["value_counts"])
# Out:
#            value_counts
# sex    ca
# Female 0             64
#        1             15
#        2             13
#        3              4
# Male   0            111
#        1             50
#        2             25
#        3             16
#        4              5

# %%
sns.countplot(x = "ca", data = heart, hue = "sex");

# %% [markdown]
# # Males have a higher propensity of developing Coronary Artery Disease (CAD) than Females

# %% [markdown]
# # Thalassemia Classification¶
#    - value 0: Null
#
#    - Value 1: normal blood flow
#
#    - Value 2: fixed defect (no blood flow in some part of the heart)
#
#    - Value 3: reversible defect (a blood flow is observed but it is not normal)

# %% [markdown]
# # How Thalassemia is related with heart disease.¶

# %%
heart.groupby(["thal"])["target"].agg(["value_counts"])
# Out:
#              value_counts
# thal target
# 0    0                  1
#      1                  1
# 1    0                 12
#      1                  6
# 2    1                130
#      0                 36
# 3    0                 89
#      1                 28

# %%
sns.countplot(x = "thal", data = heart, hue = "sex");

# %% [markdown]
# # Is Thalassemia more common in Males or Females?

# %%
heart.groupby(["sex"])["thal"].agg(["value_counts"])
# Out:
#              value_counts
# sex    thal
# Female 2               79
#        3               15
#        0                1
#        1                1
# Male   3              102
#        2               87
#        1               17
#        0                1

# %%
sns.countplot(x = "thal", data = heart, hue = "sex");

# %% [markdown]
# - Thalassemia can affect both Male and Female
# - Male patients are more frequently affected than Females

# %% [markdown]
# # How many '0' and '1' we have in our Dependent Variable¶

# %%
heart["target"].agg(["value_counts"])
# Out:
#    value_counts
# 1           165
# 0           138

# %%
sns.countplot(x = heart["target"]);

# %% [markdown]
# The ratio between 1 and 0 is much less than 1.5 which indicates that the target feature is not imbalanced.

# %% [markdown]
# # Data preparation
#     - Label Encoding

# %%
print (heart["sex"].unique())

#Replacing Female as 0 and Male as 1 in sex column in the dataset

heart["sex"] = heart["sex"].map({"Female":0, "Male":1})
print (heart["sex"].unique())
# Out:
# ['Male' 'Female']
# [1 0]

# %% [markdown]
# # Detecting Outliers¶

# %%
col = 1
plt.figure(figsize = (20, 15))
for i in heart.columns:
    if col < 14:
        plt.subplot(3, 5, col)
        plt.boxplot(heart[i])
        plt.xlabel(i)
    col = col + 1

# %% [markdown]
# - we can see that there are many outliers in the column trestbps,chol,ca,thalach,oldpeak so we will try to remove these outliers.

# %%
#Removing outliers from the column trestbps
q3=heart["trestbps"].quantile(q=0.75)
q1=heart["trestbps"].quantile(q=0.25)
IQR=q3-q1
IQR_lower_limit=int(q1-1.5*IQR)
IQR_upper_limit=int(q3+1.5*IQR)
k=heart[heart["trestbps"]>IQR_upper_limit]
heart=heart[heart["trestbps"]<IQR_upper_limit]
plt.boxplot(heart["trestbps"]);

# %%
#Removing outliers from the column chol
q3=heart["chol"].quantile(q=0.75)
q1=heart["chol"].quantile(q=0.25)
IQR=q3-q1
IQR_lower_limit=int(q1-1.5*IQR)
IQR_upper_limit=int(q3+1.5*IQR)
k=heart[heart["chol"]>IQR_upper_limit]
heart=heart[heart["chol"]<IQR_upper_limit]
plt.boxplot(heart["chol"]);

# %%
#Removing outliers from the column cal
q3=heart["ca"].quantile(q=0.75)
q1=heart["ca"].quantile(q=0.25)
IQR=q3-q1
IQR_lower_limit=int(q1-1.5*IQR)
IQR_upper_limit=int(q3+1.5*IQR)
k=heart[heart["ca"]>IQR_upper_limit]
heart=heart[heart["ca"]<IQR_upper_limit]
plt.boxplot(heart["ca"]);

# %%
#Removing outliers from the column oldpeak
q3=heart["oldpeak"].quantile(q=0.75)
q1=heart["oldpeak"].quantile(q=0.25)
IQR=q3-q1
IQR_lower_limit=int(q1-1.5*IQR)
IQR_upper_limit=int(q3+1.5*IQR)
k=heart[heart["oldpeak"]>IQR_upper_limit]
heart=heart[heart["oldpeak"]<IQR_upper_limit]
plt.boxplot(heart["oldpeak"]);

# %% [markdown]
# - Now the data is cleaned and we  will check the co-relation between the features.

# %% [markdown]
# # Correlation Heatmap

# %%
x = heart.corr()
plt.figure(figsize = (10, 8))
sns.heatmap(x, annot = True, cmap = "mako")
plt.title("Correlation Heatmap");

# %% [markdown]
# - From the above we can see that the columns are not co-related with target so we will take all the columns for model.

# %% [markdown]
# # Modelling and Evaluation.
#
# - Define the Dependent and the Independent Variables

# %%
x = heart.drop(columns = ["target"])
y = heart["target"]

# %%
x.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
#
#    ca  thal
# 0   0     1
# 2   0     2
# 3   0     2
# 4   0     2
# 5   0     1

# %%
y.head()
# Out:
# 0    1
# 2    1
# 3    1
# 4    1
# 5    1
# Name: target, dtype: int64

# %% [markdown]
# - The MinMaxscaler is a type of scaler that scales the minimum and maximum values to be 0 and 1 respectively. While the StandardScaler scales all values between min and max so that they fall within a range from min to max
# - What is the difference between MinMaxScaler and StandardScaler?
# -  what is minmaxscaler
# - StandardScaler follows Standard Normal Distribution (SND). Therefore, it makes mean = 0 and scales the data to unit variance. - ----- MinMaxScaler scales all the data features in the range [0, 1] or else in the range [-1, 1] if there are negative values in the dataset.
#
# - The fit() function calculates the values of these parameters. The transform function applies the values of the parameters on the actual data and gives the normalized value. The fit_transform() function performs both in the same step. Note that the same value is got whether we perform in 2 steps or in a single step.
#
# - GridSearchCV is a technique to search through the best parameter values from the given set of the grid of parameters. It is basically a cross-validation method. the model and the parameters are required to be fed in. Best parameter values are extracted and then the predictions are made
#
# - Cross-validation is a technique in which we train our model using the subset of the data-set and then evaluate using the complementary subset of the data-set.
#
# - The three steps involved in cross-validation are as follows :
#
#         -Reserve some portion of sample data-set.
#         -Using the rest data-set train the model.
#         -Test the model using the reserve portion of the data-set.
#
# # Advantages of cross-validation:
#
# - More accurate estimate of out-of-sample accuracy.
# - More “efficient” use of data as every observation is used for both training and testing.
#
# # Reference link:
# https://datascience.stackexchange.com/questions/12321/whats-the-difference-between-fit-and-fit-transform-in-scikit-learn-models

# %% [markdown]
# # Scaling of Data using MinMaxScaler¶

# %%
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix,classification_report
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# %%
x_scaled = MinMaxScaler()
x_scaled = x_scaled.fit_transform(x)

# %% [markdown]
# # Training the Data¶

# %%
x_train, x_test, y_train, y_test = train_test_split(x_scaled, y, test_size = 0.20, random_state = 1234)

# %% [markdown]
# # DECISION TREE CLASSIFIER¶

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
DT= DecisionTreeClassifier()

parameters = {
'criterion' : ['gini', 'entropy'],
'min_samples_split' : [2,4,6,8],
'min_samples_leaf': [1,2,3,4,5],
}
DT.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.model_selection import GridSearchCV
grid_search_cv = GridSearchCV(estimator=DT, param_grid=parameters,
                          cv=5, scoring="accuracy", n_jobs =-1)
grid_search_cv.fit(x_scaled, y)
grid_search_cv.best_params_
# Out:
# {'criterion': 'gini', 'min_samples_leaf': 4, 'min_samples_split': 6}

# %% [markdown]
# # What is Entropy in Machine Learning
#   - Entropy is the measurement of disorder or impurities in the information processed in machine   learning. It determines how a decision tree chooses to split data
#
#   We can understand the term entropy with any simple example: flipping a coin. When we flip a coin, then there can be two outcomes. However, it is difficult to conclude what would be the exact outcome while flipping a coin because there is no direct relation between flipping a coin and its outcomes. There is a 50% probability of both outcomes; then, in such scenarios, entropy would be high. This is the essence of entropy in machine learning.
#
# Mathematical Formula for Entropy
# Consider a data set having a total number of N classes, then the entropy (E) can be determined with the formula below:
#
# ![image.png](attachment:image.png)
#
# Where;
#
#
# Pi = Probability of randomly selecting an example in class I;
#
# Entropy always lies between 0 and 1, however depending on the number of classes in the dataset, it can be greater than 1. But the high value of
#
# Let's understand it with an example where we have a dataset having three colors of fruits as red, green, and yellow. Suppose we have 2 red, 2 green, and 4 yellow observations throughout the dataset. Then as per the above equation:
#
# E=−(prlog2pr+pplog2pp+pylog2py)
#
# Where;
#
# Pr = Probability of choosing red fruits;
#
# Pg = Probability of choosing green fruits and;
#
# Py = Probability of choosing yellow fruits.
#
#
# Pr = 2/8 =1/4 [As only 2 out of 8 datasets represents red fruits]
#
# Pg = 2/8 =1/4 [As only 2 out of 8 datasets represents green fruits]
#
# Py = 4/8 = 1/2 [As only 4 out of 8 datasets represents yellow fruits]
#
#
# Now our final equation will be such as;
#
# Entropy in Machine Learning
# So, entropy will be 1.5.
#
# Let's consider a case when all observations belong to the same class; then entropy will always be 0.
#
# E=−(1log21)
#
# = 0
#
# When entropy becomes 0, then the dataset has no impurity. Datasets with 0 impurities are not useful for learning. Further, if the entropy is 1, then this kind of dataset is good for learning.
#
# Entropy in Machine Learning

# %%
# !pip install pydotplus
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install graphviz
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# Creating tree like structure

# %%
# Standard process to develop  decision tree graph

from IPython.display import Image
# from sklearn.externals.six import StringIO inpace of that we have to use below library
from six import StringIO
from sklearn.tree import export_graphviz
import pydotplus,graphviz
from io import StringIO

# %%
dot_data = StringIO()
export_graphviz(DT,out_file=dot_data,filled=True,rounded=True,
               feature_names=x.columns,
               class_names=['No Disease','Disease'])
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
Image(graph.create_png())

# %% [markdown]
# ## precision, recall, and f1-score of multiclass classification models.
#
# # Accuracy tells you how many times the ML model was correct overall.
# # Precision is how good the model is at predicting a specific category.
# # Recall tells you how many times the model was able to detect a specific category.
# #recall->tp / (tp + fn)
# #The recall is the measure of our model correctly identifying True Positives.
# #Thus, for all the people who actually have heart disease,
# #recall tells us how many were correctly identified as a heart patient.
# #Layman definition: Of all the actual positive examples out there,
# #how many of them did I correctly predict to be positive?
#
# #precision of class 0 = TP of class 0/total number of object
# #What is the Precision for our model?
# #Yes, it is 0.843 or, when it predicts that a patient has heart disease, it is correct around 84% of the time.
# #precision of class 1 = TP of class 1/total number of object
# #Layman definition: Of all the positive predictions I made, how many of them are truly positive?
#
#
# #macro average = (precision of class 0 + precision of class 1)/2
#
# -  weighted average is precision of all classes merge together
# -  weighted average = (TP of class 0 + TP of class 1)/(total number of class 0 + total number of class 1)
#
# - F1-score is a measure of a model's accuracy on a dataset
# - a good F1 score means that you have low false positives and low false negatives,
# - Accuracy is used when the True Positives and True negatives are more important while
# - F1-score is used when the False Negatives and False Positives are crucial.
# - Support is the number of actual occurrences of the class in the specified dataset.

# %%
y_pred = grid_search_cv.predict(x_test)
dt_accuracy = accuracy_score(y_pred,y_test)
print(dt_accuracy)
mat = confusion_matrix(y_test,y_pred)
print(mat)
print(classification_report(y_test,y_pred))

# %%
#col-- object--- fill the nan values by the mode of the col
#col-- num-- fill the nan values by mean/median
## 20, 30,25, 79,10,2, 70, (50-60), 80, 2

# %%
# #how many patients are having chol >300 and age greater than 40
# heart[(heart['chol']>300) & (heart['age']>40)].shape

# %%
# #female patients not having heart disease
# heart[(heart['sex']==0) & (heart['target']==0)].shape

# %%
# heart[(heart['sex']==0) & (heart['target']==0)].count()

# %%
# heart[(heart['sex']==0) & (heart['chol']>500)]

# %%
# heart[heart['chol']>300].count()

# %%
# f=heart[heart['thal']==2]
# f
